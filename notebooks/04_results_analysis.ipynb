# %% [markdown]
# # 04 Results Analysis
# Evaluate model performance and visualize results.

# %%
import sys
sys.path.insert(0, '..')
import torch
import numpy as np
from src.models.architectures.mlp import VectorFieldMLP
from src.training.metrics import compute_r2, compute_rmse, compute_mae

# %%
from src.inference.predictor import VectorFieldPredictor
# predictor = VectorFieldPredictor('../models/vector_field_mlp.pth')
# predictor.load_model()
# traj = predictor.predict_trajectory(0.99, 0.01, 0.0, num_steps=200)
print('Load model and run inference here')

# %%
from src.visualization.plots import plot_trajectory
# plot_trajectory(traj['t'], traj['S'], traj['I'], traj['R'])
import matplotlib.pyplot as plt
# plt.show()
print('Visualization complete')

# %% [markdown]
# # 03 Symbolic Discovery
# Apply SINDy to recover SIR equations.

# %%
import sys
sys.path.insert(0, '..')
import pandas as pd
from src.symbolic.sindy import SINDy

# %%
df = pd.read_csv('../data/processed/sir_vector_field.csv')
sindy = SINDy()
sindy.fit(df)
eqs = sindy.get_equations()
for eq, expr in eqs.items():
    print(f'{eq} = {expr}')

# %%
print('\nExpected:')
print('  dS_dt = -beta * S * I')
print('  dI_dt =  beta * S * I - gamma * I')
print('  dR_dt =  gamma * I')
